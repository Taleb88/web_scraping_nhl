# %%
import pandas as pd

# Webpage url                                                                                                               
url = 'https://www.hockey-reference.com/teams/DET/2023.html'

# Extract tables
dfs = pd.read_html(url)

# Get the "Scoring Regular Season" table                                                                                                        
df = dfs[3]

print(df)
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk             Player                Age
# 0                 1.0       Dylan Larkin               26.0
# 1                 2.0       David Perron               34.0
# 2                 3.0    Dominik Kubalík               27.0
# 3                 4.0      Lucas Raymond               20.0
# 4                 5.0        Andrew Copp               28.0
# 5                 6.0      Moritz Seider               21.0
# 6                 7.0       Filip Hronek               25.0
# 7                 8.0  Michael Rasmussen               23.0
# 8                 9.0   Jonatan Berggren               22.0
# 9                10.0         Pius Suter               26.0
# 10               11.0        Olli Määttä               28.0
# 11               12.0    Oskar Sundqvist               28.0
# 12               13.0         Joe Veleno               23.0
# 13               14.0        Ben Chiarot               31.0
# ...

# %%
# creating excel workbook and saving data to it 
df.to_excel('2023_red_wings_scoring_regular_season.xlsx')

# %%
# save data into csv file
csv_df = pd.read_excel('2023_red_wings_scoring_regular_season.xlsx')

# %%
csv_df
# Out:
#     Unnamed: 0    Rk             Player   Age  Pos  GP    G    A  PTS  +/-  \
# 0            0   1.0       Dylan Larkin  26.0    C  80   32   47   79   -7
# 1            1   2.0       David Perron  34.0   LW  82   24   32   56   -7
# 2            2   3.0    Dominik Kubalík  27.0   LW  81   20   25   45  -15
# 3            3   4.0      Lucas Raymond  20.0   LW  74   17   28   45  -17
# 4            4   5.0        Andrew Copp  28.0    C  82    9   33   42    2
# 5            5   6.0      Moritz Seider  21.0    D  82    5   37   42  -11
# 6            6   7.0       Filip Hronek  25.0    D  60    9   29   38    8
# 7            7   8.0  Michael Rasmussen  23.0    C  56   10   19   29    2
# 8            8   9.0   Jonatan Berggren  22.0   RW  67   15   13   28  -14
# 9            9  10.0         Pius Suter  26.0    F  79   14   10   24   -3
# 10          10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9
# ...

# %%
csv_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
csv_df
# Out:
#       Rk             Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0       Dylan Larkin  26.0    C  80   32   47   79   -7   45  ...
# 1    2.0       David Perron  34.0   LW  82   24   32   56   -7   52  ...
# 2    3.0    Dominik Kubalík  27.0   LW  81   20   25   45  -15   24  ...
# 3    4.0      Lucas Raymond  20.0   LW  74   17   28   45  -17   24  ...
# 4    5.0        Andrew Copp  28.0    C  82    9   33   42    2   25  ...
# 5    6.0      Moritz Seider  21.0    D  82    5   37   42  -11   40  ...
# 6    7.0       Filip Hronek  25.0    D  60    9   29   38    8   34  ...
# 7    8.0  Michael Rasmussen  23.0    C  56   10   19   29    2   43  ...
# 8    9.0   Jonatan Berggren  22.0   RW  67   15   13   28  -14   16  ...
# 9   10.0         Pius Suter  26.0    F  79   14   10   24   -3    6  ...
# 10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9   14  ...
# 11  12.0    Oskar Sundqvist  28.0    C  52    7   14   21   -4   20  ...
# ...

# %%
csv_df.to_csv('2023_red_wings_scoring_regular_season.csv', index=False)

# %%
# sorted values via blocks
blocks_df = csv_df.sort_values(by='BLK', ascending=False)

# %%
blocks_df
# Out:
#       Rk             Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 34   NaN         Team Total   NaN  NaN  82  237  403  640 -195  648  ...
# 5    6.0      Moritz Seider  21.0    D  82    5   37   42  -11   40  ...
# 13  14.0        Ben Chiarot  31.0    D  76    5   14   19  -31   51  ...
# 10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9   14  ...
# 14  15.0        Jake Walman  26.0    D  63    9    9   18   10   45  ...
# 18  19.0    Jordan Oesterle  30.0    D  52    2    9   11   -9   19  ...
# 15  16.0          Adam Erne  27.0   LW  61    8   10   18  -12   21  ...
# 6    7.0       Filip Hronek  25.0    D  60    9   29   38    8   34  ...
# 7    8.0  Michael Rasmussen  23.0    C  56   10   19   29    2   43  ...
# 23  24.0        Robert Hägg  27.0    D  38    2    5    7   -5   26  ...
# 4    5.0        Andrew Copp  28.0    C  82    9   33   42    2   25  ...
# 12  13.0         Joe Veleno  23.0    C  81    9   11   20  -12   30  ...
# ...

# %%
# import numpy in order to shift total row to last row position
import numpy as np

red_wings_blocked_shots_2023_regular_season_df = blocks_df.iloc[np.arange(-34, len(blocks_df)-34)]
red_wings_blocked_shots_2023_regular_season_df
# Out:
#       Rk             Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 5    6.0      Moritz Seider  21.0    D  82    5   37   42  -11   40  ...
# 13  14.0        Ben Chiarot  31.0    D  76    5   14   19  -31   51  ...
# 10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9   14  ...
# 14  15.0        Jake Walman  26.0    D  63    9    9   18   10   45  ...
# 18  19.0    Jordan Oesterle  30.0    D  52    2    9   11   -9   19  ...
# 15  16.0          Adam Erne  27.0   LW  61    8   10   18  -12   21  ...
# 6    7.0       Filip Hronek  25.0    D  60    9   29   38    8   34  ...
# 7    8.0  Michael Rasmussen  23.0    C  56   10   19   29    2   43  ...
# 23  24.0        Robert Hägg  27.0    D  38    2    5    7   -5   26  ...
# 4    5.0        Andrew Copp  28.0    C  82    9   33   42    2   25  ...
# 12  13.0         Joe Veleno  23.0    C  81    9   11   20  -12   30  ...
# 9   10.0         Pius Suter  26.0    F  79   14   10   24   -3    6  ...
# ...

# %%
# save sorted blocks data to excel workbook
red_wings_blocked_shots_2023_regular_season_df.to_excel('2023_red_wings_blocks_regular_season.xlsx')

# %%
# save sorted blocks data to csv
red_wings_blocked_shots_2023_regular_season_df.to_csv('2023_red_wings_blocks_regular_season.csv', index=False)

# %%
df = pd.read_csv('2023_red_wings_scoring_regular_season.csv')
df
# Out:
#       Rk             Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0       Dylan Larkin  26.0    C  80   32   47   79   -7   45  ...
# 1    2.0       David Perron  34.0   LW  82   24   32   56   -7   52  ...
# 2    3.0    Dominik Kubalík  27.0   LW  81   20   25   45  -15   24  ...
# 3    4.0      Lucas Raymond  20.0   LW  74   17   28   45  -17   24  ...
# 4    5.0        Andrew Copp  28.0    C  82    9   33   42    2   25  ...
# 5    6.0      Moritz Seider  21.0    D  82    5   37   42  -11   40  ...
# 6    7.0       Filip Hronek  25.0    D  60    9   29   38    8   34  ...
# 7    8.0  Michael Rasmussen  23.0    C  56   10   19   29    2   43  ...
# 8    9.0   Jonatan Berggren  22.0   RW  67   15   13   28  -14   16  ...
# 9   10.0         Pius Suter  26.0    F  79   14   10   24   -3    6  ...
# 10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9   14  ...
# 11  12.0    Oskar Sundqvist  28.0    C  52    7   14   21   -4   20  ...
# ...

# %%
df.loc[df['Pos'] == 'G']
# Out:
#       Rk            Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 28  29.0   Magnus Hellberg  31.0   G  17  0  0    0    0    0  ...   876.0
# 30  31.0       Ville Husso  27.0   G  56  0  0    0    0    0  ...  3220.0
# 32  33.0  Alex Nedeljkovic  27.0   G  15  0  0    0    0    2  ...   833.0
#
#      ATOI  OPS  DPS   PS  BLK  HIT  FOW  FOL  FO%
# 28  51:33  0.0  0.0  1.5    0    0    0    0  NaN
# 30  57:30  0.0  0.0  7.7    0    0    0    0  NaN
# 32  55:31  0.0  0.0  2.2    0    0    0    0  NaN
#
# [3 rows x 29 columns]

# %%
goalies_df = df.loc[df['Pos'] == 'G']

goalies_df
# Out:
#       Rk            Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 28  29.0   Magnus Hellberg  31.0   G  17  0  0    0    0    0  ...   876.0
# 30  31.0       Ville Husso  27.0   G  56  0  0    0    0    0  ...  3220.0
# 32  33.0  Alex Nedeljkovic  27.0   G  15  0  0    0    0    2  ...   833.0
#
#      ATOI  OPS  DPS   PS  BLK  HIT  FOW  FOL  FO%
# 28  51:33  0.0  0.0  1.5    0    0    0    0  NaN
# 30  57:30  0.0  0.0  7.7    0    0    0    0  NaN
# 32  55:31  0.0  0.0  2.2    0    0    0    0  NaN
#
# [3 rows x 29 columns]

# %%
goalies_df.sort_values(by=['GP'], ascending=False)
# Out:
#       Rk            Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 30  31.0       Ville Husso  27.0   G  56  0  0    0    0    0  ...  3220.0
# 28  29.0   Magnus Hellberg  31.0   G  17  0  0    0    0    0  ...   876.0
# 32  33.0  Alex Nedeljkovic  27.0   G  15  0  0    0    0    2  ...   833.0
#
#      ATOI  OPS  DPS   PS  BLK  HIT  FOW  FOL  FO%
# 30  57:30  0.0  0.0  7.7    0    0    0    0  NaN
# 28  51:33  0.0  0.0  1.5    0    0    0    0  NaN
# 32  55:31  0.0  0.0  2.2    0    0    0    0  NaN
#
# [3 rows x 29 columns]

# %%
goalies_df.to_excel('2023_red_wings_goalies_regular_season.xlsx')
goalies_df.to_csv('2023_red_wings_goalies_regular_season.csv', index=False)

# %%
for index,row in goalies_df.iterrows():
    print(index,row['Player'])
# Out:
# 28 Magnus Hellberg
# 30 Ville Husso
# 32 Alex Nedeljkovic

# %%
goalies_updated_df = goalies_df.drop(['Rk'], axis=1)

# %%
goalies_updated_df
# Out:
#               Player   Age Pos  GP  G  A  PTS  +/-  PIM  EV  ...     TOI  \
# 28   Magnus Hellberg  31.0   G  17  0  0    0    0    0   0  ...   876.0
# 30       Ville Husso  27.0   G  56  0  0    0    0    0   0  ...  3220.0
# 32  Alex Nedeljkovic  27.0   G  15  0  0    0    0    2   0  ...   833.0
#
#      ATOI  OPS  DPS   PS  BLK  HIT  FOW  FOL FO%
# 28  51:33  0.0  0.0  1.5    0    0    0    0 NaN
# 30  57:30  0.0  0.0  7.7    0    0    0    0 NaN
# 32  55:31  0.0  0.0  2.2    0    0    0    0 NaN
#
# [3 rows x 28 columns]

# %%
goalies_updated_df.to_excel('2023_red_wings_goalies_regular_season.xlsx')
goalies_updated_df.to_csv('2023_red_wings_goalies_regular_season.csv', index=False)

# %%
df
# Out:
#       Rk             Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0       Dylan Larkin  26.0    C  80   32   47   79   -7   45  ...
# 1    2.0       David Perron  34.0   LW  82   24   32   56   -7   52  ...
# 2    3.0    Dominik Kubalík  27.0   LW  81   20   25   45  -15   24  ...
# 3    4.0      Lucas Raymond  20.0   LW  74   17   28   45  -17   24  ...
# 4    5.0        Andrew Copp  28.0    C  82    9   33   42    2   25  ...
# 5    6.0      Moritz Seider  21.0    D  82    5   37   42  -11   40  ...
# 6    7.0       Filip Hronek  25.0    D  60    9   29   38    8   34  ...
# 7    8.0  Michael Rasmussen  23.0    C  56   10   19   29    2   43  ...
# 8    9.0   Jonatan Berggren  22.0   RW  67   15   13   28  -14   16  ...
# 9   10.0         Pius Suter  26.0    F  79   14   10   24   -3    6  ...
# 10  11.0        Olli Määttä  28.0    D  78    6   17   23   -9   14  ...
# 11  12.0    Oskar Sundqvist  28.0    C  52    7   14   21   -4   20  ...
# ...

# %%
forwards_df = df.loc[(df['Pos'] == 'RW') | (df['Pos'] == 'LW') | (df['Pos'] == 'C')]

# %%
forwards_df
# Out:
#       Rk             Player   Age Pos  GP   G   A  PTS  +/-  PIM  ...     TOI  \
# 0    1.0       Dylan Larkin  26.0   C  80  32  47   79   -7   45  ...  1564.0
# 1    2.0       David Perron  34.0  LW  82  24  32   56   -7   52  ...  1387.0
# 2    3.0    Dominik Kubalík  27.0  LW  81  20  25   45  -15   24  ...  1208.0
# 3    4.0      Lucas Raymond  20.0  LW  74  17  28   45  -17   24  ...  1286.0
# 4    5.0        Andrew Copp  28.0   C  82   9  33   42    2   25  ...  1489.0
# 7    8.0  Michael Rasmussen  23.0   C  56  10  19   29    2   43  ...   845.0
# 8    9.0   Jonatan Berggren  22.0  RW  67  15  13   28  -14   16  ...   902.0
# 11  12.0    Oskar Sundqvist  28.0   C  52   7  14   21   -4   20  ...   742.0
# 12  13.0         Joe Veleno  23.0   C  81   9  11   20  -12   30  ...  1035.0
# 15  16.0          Adam Erne  27.0  LW  61   8  10   18  -12   21  ...   816.0
# 16  17.0       Robby Fabbri  27.0   C  28   7   9   16   -1   22  ...   448.0
# ...

# %%
del forwards_df['Rk']

# %%
forwards_df
# Out:
#                Player   Age Pos  GP   G   A  PTS  +/-  PIM  EV  ...     TOI  \
# 0        Dylan Larkin  26.0   C  80  32  47   79   -7   45  15  ...  1564.0
# 1        David Perron  34.0  LW  82  24  32   56   -7   52  18  ...  1387.0
# 2     Dominik Kubalík  27.0  LW  81  20  25   45  -15   24  13  ...  1208.0
# 3       Lucas Raymond  20.0  LW  74  17  28   45  -17   24  12  ...  1286.0
# 4         Andrew Copp  28.0   C  82   9  33   42    2   25   7  ...  1489.0
# 7   Michael Rasmussen  23.0   C  56  10  19   29    2   43  10  ...   845.0
# 8    Jonatan Berggren  22.0  RW  67  15  13   28  -14   16  10  ...   902.0
# 11    Oskar Sundqvist  28.0   C  52   7  14   21   -4   20   5  ...   742.0
# 12         Joe Veleno  23.0   C  81   9  11   20  -12   30   8  ...  1035.0
# 15          Adam Erne  27.0  LW  61   8  10   18  -12   21   8  ...   816.0
# 16       Robby Fabbri  27.0   C  28   7   9   16   -1   22   4  ...   448.0
# ...

# %%
forwards_df.to_excel('2023_red_wings_forwards_regular_season.xlsx')
forwards_df.to_csv('2023_red_wings_forwards_regular_season.csv', index=False)
