# %%
import pandas as pd

# Webpage url                                                                                                               
url = 'https://www.hockey-reference.com/teams/DET/2023.html'

# Extract tables
dfs = pd.read_html(url)

# Get the "Scoring Regular Season" table                                                                                                        
df = dfs[3]

print(df)
# Out:
#    Unnamed: 0_level_0  Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk              Player                Age
# 0                 1.0      Artemi Panarin               31.0
# 1                 2.0      Mika Zibanejad               29.0
# 2                 3.0            Adam Fox               24.0
# 3                 4.0    Vincent Trocheck               29.0
# 4                 5.0       Chris Kreider               31.0
# 5                 6.0        Filip Chytil               23.0
# 6                 7.0      K'Andre Miller               23.0
# 7                 8.0         Kaapo Kakko               21.0
# 8                 9.0   Alexis Lafrenière               21.0
# 9                10.0     Barclay Goodrow               29.0
# 10               11.0        Jacob Trouba               28.0
# 11               12.0         Jimmy Vesey               29.0
# 12               13.0  Vladimir Tarasenko               31.0
# ...

# %%
# creating excel workbook and saving data to it 
df.to_excel('2023_rangers_scoring_regular_season.xlsx')

# %%
# save data into csv file
csv_df = pd.read_excel('2023_rangers_scoring_regular_season.xlsx')

# %%
csv_df
# Out:
#     Unnamed: 0    Rk              Player   Age  Pos  GP    G    A  PTS  +/-  \
# 0            0   1.0      Artemi Panarin  31.0   LW  82   29   63   92    4
# 1            1   2.0      Mika Zibanejad  29.0    C  82   39   52   91   25
# 2            2   3.0            Adam Fox  24.0    D  82   12   60   72   28
# 3            3   4.0    Vincent Trocheck  29.0    C  82   22   42   64    3
# 4            4   5.0       Chris Kreider  31.0   LW  79   36   18   54   21
# 5            5   6.0        Filip Chytil  23.0    C  74   22   23   45   15
# 6            6   7.0      K'Andre Miller  23.0    D  79    9   34   43   12
# 7            7   8.0         Kaapo Kakko  21.0   RW  82   18   22   40   12
# 8            8   9.0   Alexis Lafrenière  21.0   LW  81   16   23   39   10
# 9            9  10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3
# 10          10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7
# ...

# %%
csv_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
csv_df
# Out:
#       Rk              Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0      Artemi Panarin  31.0   LW  82   29   63   92    4   36  ...
# 1    2.0      Mika Zibanejad  29.0    C  82   39   52   91   25   20  ...
# 2    3.0            Adam Fox  24.0    D  82   12   60   72   28   34  ...
# 3    4.0    Vincent Trocheck  29.0    C  82   22   42   64    3   58  ...
# 4    5.0       Chris Kreider  31.0   LW  79   36   18   54   21   26  ...
# 5    6.0        Filip Chytil  23.0    C  74   22   23   45   15   30  ...
# 6    7.0      K'Andre Miller  23.0    D  79    9   34   43   12   37  ...
# 7    8.0         Kaapo Kakko  21.0   RW  82   18   22   40   12    8  ...
# 8    9.0   Alexis Lafrenière  21.0   LW  81   16   23   39   10   33  ...
# 9   10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3   58  ...
# 10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7   63  ...
# 11  12.0         Jimmy Vesey  29.0   LW  81   11   14   25   13   20  ...
# ...

# %%
csv_df.to_csv('2023_rangers_scoring_regular_season.csv', index=False)

# %%
# sorted values via blocks
blocks_df = csv_df.sort_values(by='BLK', ascending=False)

# %%
blocks_df
# Out:
#       Rk              Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 32   NaN          Team Total   NaN  NaN  82  273  472  745  191  605  ...
# 10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7   63  ...
# 13  14.0    Braden Schneider  21.0    D  81    5   13   18    9   16  ...
# 2    3.0            Adam Fox  24.0    D  82   12   60   72   28   34  ...
# 6    7.0      K'Andre Miller  23.0    D  79    9   34   43   12   37  ...
# 14  15.0       Ryan Lindgren  24.0    D  63    1   17   18   29   45  ...
# 9   10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3   58  ...
# 19  20.0          Ben Harpur  28.0    D  42    1    5    6    0   20  ...
# 1    2.0      Mika Zibanejad  29.0    C  82   39   52   91   25   20  ...
# 3    4.0    Vincent Trocheck  29.0    C  82   22   42   64    3   58  ...
# 11  12.0         Jimmy Vesey  29.0   LW  81   11   14   25   13   20  ...
# 5    6.0        Filip Chytil  23.0    C  74   22   23   45   15   30  ...
# ...

# %%
# import numpy in order to shift total row to last row position
import numpy as np

rangers_blocked_shots_2023_regular_season_df = blocks_df.iloc[np.arange(-32, len(blocks_df)-32)]
rangers_blocked_shots_2023_regular_season_df
# Out:
#       Rk              Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7   63  ...
# 13  14.0    Braden Schneider  21.0    D  81    5   13   18    9   16  ...
# 2    3.0            Adam Fox  24.0    D  82   12   60   72   28   34  ...
# 6    7.0      K'Andre Miller  23.0    D  79    9   34   43   12   37  ...
# 14  15.0       Ryan Lindgren  24.0    D  63    1   17   18   29   45  ...
# 9   10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3   58  ...
# 19  20.0          Ben Harpur  28.0    D  42    1    5    6    0   20  ...
# 1    2.0      Mika Zibanejad  29.0    C  82   39   52   91   25   20  ...
# 3    4.0    Vincent Trocheck  29.0    C  82   22   42   64    3   58  ...
# 11  12.0         Jimmy Vesey  29.0   LW  81   11   14   25   13   20  ...
# 5    6.0        Filip Chytil  23.0    C  74   22   23   45   15   30  ...
# 22  23.0        Niko Mikkola  26.0    D  31    1    2    3    4   23  ...
# ...

# %%
# save sorted blocks data to excel workbook
rangers_blocked_shots_2023_regular_season_df.to_excel('2023_rangers_blocks_regular_season.xlsx')

# %%
# save sorted blocks data to csv
rangers_blocked_shots_2023_regular_season_df.to_csv('2023_rangers_blocks_regular_season.csv', index=False)

# %%
df = pd.read_csv('2023_rangers_scoring_regular_season.csv')
df
# Out:
#       Rk              Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0      Artemi Panarin  31.0   LW  82   29   63   92    4   36  ...
# 1    2.0      Mika Zibanejad  29.0    C  82   39   52   91   25   20  ...
# 2    3.0            Adam Fox  24.0    D  82   12   60   72   28   34  ...
# 3    4.0    Vincent Trocheck  29.0    C  82   22   42   64    3   58  ...
# 4    5.0       Chris Kreider  31.0   LW  79   36   18   54   21   26  ...
# 5    6.0        Filip Chytil  23.0    C  74   22   23   45   15   30  ...
# 6    7.0      K'Andre Miller  23.0    D  79    9   34   43   12   37  ...
# 7    8.0         Kaapo Kakko  21.0   RW  82   18   22   40   12    8  ...
# 8    9.0   Alexis Lafrenière  21.0   LW  81   16   23   39   10   33  ...
# 9   10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3   58  ...
# 10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7   63  ...
# 11  12.0         Jimmy Vesey  29.0   LW  81   11   14   25   13   20  ...
# ...

# %%
df.loc[df['Pos'] == 'G']
# Out:
#       Rk           Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 27  28.0   Jaroslav Halák  37.0   G  25  0  1    1    0    0  ...  1454.0
# 28  29.0  Igor Shesterkin  27.0   G  58  0  1    1    0    2  ...  3489.0
#
#      ATOI  OPS  DPS    PS  BLK  HIT  FOW  FOL  FO%
# 27  58:09  0.0  0.0   3.8    0    0    0    0  NaN
# 28  60:09  0.0  0.0  11.8    0    0    0    0  NaN
#
# [2 rows x 29 columns]

# %%
goalies_df = df.loc[df['Pos'] == 'G']

goalies_df
# Out:
#       Rk           Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 27  28.0   Jaroslav Halák  37.0   G  25  0  1    1    0    0  ...  1454.0
# 28  29.0  Igor Shesterkin  27.0   G  58  0  1    1    0    2  ...  3489.0
#
#      ATOI  OPS  DPS    PS  BLK  HIT  FOW  FOL  FO%
# 27  58:09  0.0  0.0   3.8    0    0    0    0  NaN
# 28  60:09  0.0  0.0  11.8    0    0    0    0  NaN
#
# [2 rows x 29 columns]

# %%
goalies_df.sort_values(by=['GP'], ascending=False)
# Out:
#       Rk           Player   Age Pos  GP  G  A  PTS  +/-  PIM  ...     TOI  \
# 28  29.0  Igor Shesterkin  27.0   G  58  0  1    1    0    2  ...  3489.0
# 27  28.0   Jaroslav Halák  37.0   G  25  0  1    1    0    0  ...  1454.0
#
#      ATOI  OPS  DPS    PS  BLK  HIT  FOW  FOL  FO%
# 28  60:09  0.0  0.0  11.8    0    0    0    0  NaN
# 27  58:09  0.0  0.0   3.8    0    0    0    0  NaN
#
# [2 rows x 29 columns]

# %%
goalies_df.to_excel('2023_rangers_goalies_regular_season.xlsx')
goalies_df.to_csv('2023_rangers_goalies_regular_season.csv', index=False)

# %%
for index,row in goalies_df.iterrows():
    print(index,row['Player'])
# Out:
# 27 Jaroslav Halák
# 28 Igor Shesterkin

# %%
goalies_updated_df = goalies_df.drop(['Rk'], axis=1)

# %%
goalies_updated_df
# Out:
#              Player   Age Pos  GP  G  A  PTS  +/-  PIM  EV  ...     TOI  \
# 27   Jaroslav Halák  37.0   G  25  0  1    1    0    0   0  ...  1454.0
# 28  Igor Shesterkin  27.0   G  58  0  1    1    0    2   0  ...  3489.0
#
#      ATOI  OPS  DPS    PS  BLK  HIT  FOW  FOL FO%
# 27  58:09  0.0  0.0   3.8    0    0    0    0 NaN
# 28  60:09  0.0  0.0  11.8    0    0    0    0 NaN
#
# [2 rows x 28 columns]

# %%
goalies_updated_df.to_excel('2023_rangers_goalies_regular_season.xlsx')
goalies_updated_df.to_csv('2023_rangers_goalies_regular_season.csv', index=False)

# %%
df
# Out:
#       Rk              Player   Age  Pos  GP    G    A  PTS  +/-  PIM  ...  \
# 0    1.0      Artemi Panarin  31.0   LW  82   29   63   92    4   36  ...
# 1    2.0      Mika Zibanejad  29.0    C  82   39   52   91   25   20  ...
# 2    3.0            Adam Fox  24.0    D  82   12   60   72   28   34  ...
# 3    4.0    Vincent Trocheck  29.0    C  82   22   42   64    3   58  ...
# 4    5.0       Chris Kreider  31.0   LW  79   36   18   54   21   26  ...
# 5    6.0        Filip Chytil  23.0    C  74   22   23   45   15   30  ...
# 6    7.0      K'Andre Miller  23.0    D  79    9   34   43   12   37  ...
# 7    8.0         Kaapo Kakko  21.0   RW  82   18   22   40   12    8  ...
# 8    9.0   Alexis Lafrenière  21.0   LW  81   16   23   39   10   33  ...
# 9   10.0     Barclay Goodrow  29.0   RW  82   11   20   31    3   58  ...
# 10  11.0        Jacob Trouba  28.0    D  82    8   22   30    7   63  ...
# 11  12.0         Jimmy Vesey  29.0   LW  81   11   14   25   13   20  ...
# ...

# %%
forwards_df = df.loc[(df['Pos'] == 'RW') | (df['Pos'] == 'LW') | (df['Pos'] == 'C')]

# %%
forwards_df
# Out:
#       Rk              Player   Age Pos  GP   G   A  PTS  +/-  PIM  ...  \
# 0    1.0      Artemi Panarin  31.0  LW  82  29  63   92    4   36  ...
# 1    2.0      Mika Zibanejad  29.0   C  82  39  52   91   25   20  ...
# 3    4.0    Vincent Trocheck  29.0   C  82  22  42   64    3   58  ...
# 4    5.0       Chris Kreider  31.0  LW  79  36  18   54   21   26  ...
# 5    6.0        Filip Chytil  23.0   C  74  22  23   45   15   30  ...
# 7    8.0         Kaapo Kakko  21.0  RW  82  18  22   40   12    8  ...
# 8    9.0   Alexis Lafrenière  21.0  LW  81  16  23   39   10   33  ...
# 9   10.0     Barclay Goodrow  29.0  RW  82  11  20   31    3   58  ...
# 11  12.0         Jimmy Vesey  29.0  LW  81  11  14   25   13   20  ...
# 12  13.0  Vladimir Tarasenko  31.0  RW  31   8  13   21    4    0  ...
# 15  16.0        Patrick Kane  34.0  RW  19   5   7   12    1    6  ...
# 16  17.0         Tyler Motte  27.0   C  24   5   5   10    2    2  ...
# ...

# %%
del forwards_df['Rk']

# %%
forwards_df
# Out:
#                 Player   Age Pos  GP   G   A  PTS  +/-  PIM  EV  ...     TOI  \
# 0       Artemi Panarin  31.0  LW  82  29  63   92    4   36  20  ...  1608.0
# 1       Mika Zibanejad  29.0   C  82  39  52   91   25   20  18  ...  1637.0
# 3     Vincent Trocheck  29.0   C  82  22  42   64    3   58  13  ...  1584.0
# 4        Chris Kreider  31.0  LW  79  36  18   54   21   26  24  ...  1455.0
# 5         Filip Chytil  23.0   C  74  22  23   45   15   30  19  ...  1087.0
# 7          Kaapo Kakko  21.0  RW  82  18  22   40   12    8  18  ...  1255.0
# 8    Alexis Lafrenière  21.0  LW  81  16  23   39   10   33  13  ...  1233.0
# 9      Barclay Goodrow  29.0  RW  82  11  20   31    3   58  10  ...  1162.0
# 11         Jimmy Vesey  29.0  LW  81  11  14   25   13   20  10  ...  1102.0
# 12  Vladimir Tarasenko  31.0  RW  31   8  13   21    4    0   7  ...   494.0
# 15        Patrick Kane  34.0  RW  19   5   7   12    1    6   3  ...   332.0
# ...

# %%
forwards_df.to_excel('2023_rangers_forwards_regular_season.xlsx')
forwards_df.to_csv('2023_rangers_forwards_regular_season.csv', index=False)
