# %%
import pandas as pd

# %%
url = 'https://www.hockey-reference.com/teams/TOR/2023.html'

# %%
dfs = pd.read_html(url)

# %%
df = dfs[4]
print(df)
# Out:
#    Unnamed: 0_level_0       Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    Rk                   Player                Age
# 0                 1.0             Mitch Marner               25.0
# 1                 2.0         William Nylander               26.0
# 2                 3.0          Auston Matthews               25.0
# 3                 4.0             John Tavares               32.0
# 4                 5.0          Michael Bunting               27.0
# 5                 6.0            Morgan Rielly               28.0
# 6                 7.0           Calle Järnkrok               31.0
# 7                 8.0        Alexander Kerfoot               28.0
# 8                 9.0              David Kämpf               28.0
# 9                10.0            Mark Giordano               39.0
# 10               11.0           Pierre Engvall               26.0
# 11               12.0            Rasmus Sandin               22.0
# ...

# %%
# saving data to spreadsheet and csv (removed first row manually)
df.to_excel('2023_maple_leafs_scoring_regular_season.xlsx')
df.to_csv('2023_maple_leafs_scoring_regular_season.csv',index=False)
